# %% [markdown]
# # Maximum Difference Between Node and Ancestor
#
# Given the root of a binary tree, find the maximum value v for which there exist different nodes a and b where v = |a.val - b.val| and a is an ancestor of b.
#
# A node a is an ancestor of b if either: any child of a is equal to b or any child of a is an ancestor of b.
#
# **Example 1:**
# ```
#                 8
#              /     \
#             3      10
#            / \       \
#           1   6      14
#              / \    /
#             4   7  13
#
# Input: root = [8,3,10,1,6,null,14,null,null,4,7,13]
# Output: 7
# Explanation: We have various ancestor-node differences, some of which are given below :
# |8 - 3| = 5
# |3 - 7| = 4
# |8 - 1| = 7
# |10 - 13| = 3
# Among all possible differences, the maximum value of 7 is obtained by |8 - 1| = 7.
# ```
# **Example 2:**
# ```
#      1
#        \
#         2
#          \
#           0
#         /
#        3
# Input: root = [1,null,2,null,0,3]
# Output: 3
# ```
# **Constraints:**
# ```
# The number of nodes in the tree is in the range [2, 5000].
# 0 <= Node.val <= 105
# ```

# %% [markdown]
# ### Approach - I

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        res = 0
        def dfs(node):
            nonlocal res
            if not node: return math.inf, -math.inf
            leftmin, leftmax = dfs(node.left)
            rightmin, rightmax = dfs(node.right)
            curmin, curmax = min(leftmin,rightmin, node.val), max(leftmax, rightmax, node.val)
            res = max(res, abs(node.val - curmin), abs(curmax- node.val))
            return curmin, curmax
        dfs(root)
        return res

# %% [markdown]
# ### Approach - II

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        def dfs(curr, cur_min, cur_max):

            if not curr:
                return cur_max - cur_min
            
            cur_min = min(cur_min,curr.val)
            cur_max = max(cur_max, curr.val)
            return max(dfs(curr.left,cur_min,cur_max),dfs(curr.right,cur_min,cur_max))
        
        return dfs(root,root.val,root.val)

# %% [markdown]
# ### Approach - III

# %%
'''
values are bounded, theyre 0 +
and 2 nodes guaranteed

lets just bubble up the max and min node
then just calc 
then bubble up max and min from both children
'''
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        def find_difference(node):
            min_left, max_left = inf, -inf
            min_right, max_right = inf, -inf

            if node.left:
                min_left, max_left = find_difference(node.left)
            if node.right:
                min_right, max_right = find_difference(node.right)
            
            min_children = min(min_left, min_right, node.val)
            max_children = max(max_left, max_right, node.val)

            max_difference = max(abs(node.val - min_children), abs(node.val - max_children))

            self.max_difference = max(self.max_difference, max_difference)

            return (min_children, max_children)


        self.max_difference = 0
        find_difference(root)
        return self.max_difference

# %% [markdown]
# ### Approach - IV

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:

        # def dfs(node, dif, ancestors):

        #     if not node:
        #         return dif
        #     elif node in seen:
        #         return dif
        #     if ancestors:
        #         dif = max([abs(anc.val-node.val) for anc in ancestors])
        #     seen.add(node)
        #     if node.left:
        #         dif = max(dif, dfs(node.left, dif, ancestors+[node]))
        #     if node.right:
        #         dif = max(dif, dfs(node.right, dif, ancestors+[node]))
        #     return dif 
        def dfs(node, dif, ancestors, max_ancestor, min_ancestor):

            if not node:
                return dif
            elif node in seen:
                return dif
            if ancestors and (node.val<min_ancestor or node.val>max_ancestor):
                dif = max(abs(node.val-min_ancestor), abs(node.val-max_ancestor))
                min_ancestor = min(node.val, min_ancestor)
                max_ancestor = max(node.val, max_ancestor)
                
                #dif = max([abs(anc.val-node.val) for anc in ancestors])
            seen.add(node)
            if node.left:
                dif = max(dif, dfs(node.left, dif, ancestors+[node], max_ancestor, min_ancestor))
            if node.right:
                dif = max(dif, dfs(node.right, dif, ancestors+[node],max_ancestor, min_ancestor))
            return dif            

        seen = set()    
        return dfs(root, 0, [], root.val, root.val)

# %% [markdown]
# ### Approach - V

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        if( root == None or root.left == None and root.right == None):
            return 0
        lst , max_val = self.help(root)

        return max_val

    def help(self , root ):
        if(root == None):
            return [] , 0
        
        left , max_l = self.help(root.left)

        right , max_r = self.help(root.right)

        if( max_l == None and max_r == None):
            return [root.val] , 0
        else:
            new_lst = left + right
            max_val = max(max_l , max_r)
            for m in new_lst:
                if( abs(root.val - m) > max_val):
                    max_val = abs(root.val - m)

            new_lst.append(root.val)
            return new_lst , max_val

# %% [markdown]
# ### Approach - VI

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        if not root:
            return 0
        return self.maxAncestorDiffHelper(root, root.val, root.val)

    def maxAncestorDiffHelper(self, root: TreeNode, maxV: int, minV: int) -> int:
        
        if not root.left and not root.right:
            return max(abs(root.val - maxV), abs(root.val - minV))

        left, right = 0, 0
        if root.right:
            right = self.maxAncestorDiffHelper(root.right, max(maxV, root.val), min(minV, root.val))    
        if root.left:
            left = self.maxAncestorDiffHelper(root.left, max(maxV, root.val), min(minV, root.val))
        
        return max(left, right, abs(root.val - maxV), abs(root.val - minV))

# %% [markdown]
# ### Approach - VII

# %%
'''
note we can go top down instead of bubble up...
'''
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        self.max_difference = 0
        children_vals = {}
        stack = [(root, root.val, root.val)]
        while stack:
            node, current_min, current_max = stack.pop()
            self.max_difference = max(self.max_difference, abs(node.val - current_min), abs(node.val - current_max))
            if node.right:
                stack.append((node.right, min(node.val, current_min), max(node.val, current_max)))
            if node.left:
                stack.append((node.left, min(node.val, current_min), max(node.val, current_max)))

        return self.max_difference

# %% [markdown]
# ### Approach - VII

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        if not root:
            return 0
        mval = 0
        stack = []
        prevmax = prevmin = root.val
        while stack or root:
            while root:
                diff = max(abs(prevmax - root.val), abs(prevmin - root.val))
                mval = max(mval, diff)
                prevmax = max(prevmax, root.val)
                prevmin = min(prevmin, root.val)
                stack.append([root, prevmax, prevmin])
                root = root.left
            root, prevmax, prevmin = stack.pop()
            root = root.right
        return mval

# %% [markdown]
# ### Approach - IX

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        
        max_diff = -float("inf")
        
        def dfs(root):
            if not root:
                return float("inf"), -float("inf")
            nonlocal max_diff

            ls, lh = dfs(root.left)

            rs, rh = dfs(root.right)
                
            s = min(ls, rs)
            h = max(lh, rh)
            
            if s != float("inf"):
                max_diff = max(max_diff, abs(root.val - s))
            if h != -float("inf"):
                max_diff = max(max_diff, abs(root.val - h))
            return min(root.val, s), max(root.val, h)
            
        dfs(root)
        
        
        return max_diff if max_diff != -float("inf") else 0

# %% [markdown]
# ### Approach - X

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:

        max_diff = 0

        def recurse(root):
            nonlocal max_diff
            curr_min, curr_max = root.val, root.val
            for node in [root.left, root.right]:
                if not node:
                    continue
                child_min, child_max = recurse(node)
                curr_diff = max(abs(root.val-child_min), abs(root.val-child_max))
                curr_min = min(child_min, curr_min)
                curr_max = max(child_max, curr_max)
                max_diff = max(max_diff, curr_diff)
            
            return curr_min, curr_max
        recurse(root)
        return max_diff
